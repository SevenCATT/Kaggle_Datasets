# %% [markdown]
# 第一次实战做kaggle上的dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('Hotel Reservations.csv')
df.head(10)
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
# 5   INN00006             2               0                     0
# 6   INN00007             2               0                     1
# 7   INN00008             2               0                     1
# 8   INN00009             3               0                     0
# 9   INN00010             2               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
# 5                  2       Meal Plan 2                           0
# 6                  3       Meal Plan 1                           0
# 7                  3       Meal Plan 1                           0
# 8                  4       Meal Plan 1                           0
# 9                  5       Meal Plan 1                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# 1        Room_Type 1          5          2018             11             6
# 2        Room_Type 1          1          2018              2            28
# 3        Room_Type 1        211          2018              5            20
# 4        Room_Type 1         48          2018              4            11
# 5        Room_Type 1        346          2018              9            13
# 6        Room_Type 1         34          2017             10            15
# 7        Room_Type 4         83          2018             12            26
# 8        Room_Type 1        121          2018              7             6
# 9        Room_Type 4         44          2018             10            18
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0             Offline               0                             0
# 1              Online               0                             0
# 2              Online               0                             0
# 3              Online               0                             0
# 4              Online               0                             0
# 5              Online               0                             0
# 6              Online               0                             0
# 7              Online               0                             0
# 8             Offline               0                             0
# 9              Online               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
# 5                                     0              115.00
# 6                                     0              107.55
# 7                                     0              105.61
# 8                                     0               96.90
# 9                                     0              133.44
#
#    no_of_special_requests booking_status
# 0                       0   Not_Canceled
# 1                       1   Not_Canceled
# 2                       0       Canceled
# 3                       0       Canceled
# 4                       0       Canceled
# 5                       1       Canceled
# 6                       1   Not_Canceled
# 7                       1   Not_Canceled
# 8                       1   Not_Canceled
# 9                       3   Not_Canceled

# %% [markdown]
# 预测客户兑现或者取消预订

# %% [markdown]
# 用什么算法？是否要清洗数据？怎么把文字信息转换为数字信息？

# %% [markdown]
# ### <font color=#0dd3de>将字符串改成数字的两种方法</font>

# %% [markdown]
# #### 第一种 映射

# %%
df['room_type_reserved'] = pd.factorize(df['room_type_reserved'])[0].astype(int)

# %%
df.head(10)
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
# 5   INN00006             2               0                     0
# 6   INN00007             2               0                     1
# 7   INN00008             2               0                     1
# 8   INN00009             3               0                     0
# 9   INN00010             2               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
# 5                  2       Meal Plan 2                           0
# 6                  3       Meal Plan 1                           0
# 7                  3       Meal Plan 1                           0
# 8                  4       Meal Plan 1                           0
# 9                  5       Meal Plan 1                           0
#
#    room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0                   0        224          2017             10             2
# 1                   0          5          2018             11             6
# 2                   0          1          2018              2            28
# 3                   0        211          2018              5            20
# 4                   0         48          2018              4            11
# 5                   0        346          2018              9            13
# 6                   0         34          2017             10            15
# 7                   1         83          2018             12            26
# 8                   0        121          2018              7             6
# 9                   1         44          2018             10            18
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0             Offline               0                             0
# 1              Online               0                             0
# 2              Online               0                             0
# 3              Online               0                             0
# 4              Online               0                             0
# 5              Online               0                             0
# 6              Online               0                             0
# 7              Online               0                             0
# 8             Offline               0                             0
# 9              Online               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
# 5                                     0              115.00
# 6                                     0              107.55
# 7                                     0              105.61
# 8                                     0               96.90
# 9                                     0              133.44
#
#    no_of_special_requests booking_status
# 0                       0   Not_Canceled
# 1                       1   Not_Canceled
# 2                       0       Canceled
# 3                       0       Canceled
# 4                       0       Canceled
# 5                       1       Canceled
# 6                       1   Not_Canceled
# 7                       1   Not_Canceled
# 8                       1   Not_Canceled
# 9                       3   Not_Canceled

# %% [markdown]
# #### 第二种 One-hot 独热编码

# %% [markdown]
# 使用第一种方法将所有特征数字化

# %%
df['room_type_reserved'] = pd.factorize(df['room_type_reserved'])[0].astype(int)
df['type_of_meal_plan'] = pd.factorize(df['type_of_meal_plan'])[0].astype(int)
df['market_segment_type'] = pd.factorize(df['market_segment_type'])[0].astype(int)
df['booking_status'] = pd.factorize(df['booking_status'])[0].astype(int)
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights  type_of_meal_plan  required_car_parking_space  \
# 0                  2                  0                           0
# 1                  3                  1                           0
# 2                  1                  0                           0
# 3                  2                  0                           0
# 4                  1                  1                           0
#
#    room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0                   0        224          2017             10             2
# 1                   0          5          2018             11             6
# 2                   0          1          2018              2            28
# 3                   0        211          2018              5            20
# 4                   0         48          2018              4            11
#
#    market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0                    0               0                             0
# 1                    1               0                             0
# 2                    1               0                             0
# 3                    1               0                             0
# 4                    1               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests  booking_status
# 0                       0               0
# 1                       1               0
# 2                       0               1
# 3                       0               1
# 4                       0               1

# %% [markdown]
# 是否有种方法可以让不同字符串变成我想要的特定值 例如 type_of_meal_plan 中，Not select 为0，Meal plan1 为1

# %%
df.corr(numeric_only=True)
# Out:
#                                       no_of_adults  no_of_children  \
# no_of_adults                              1.000000       -0.019787
# no_of_children                           -0.019787        1.000000
# no_of_weekend_nights                      0.103316        0.029478
# no_of_week_nights                         0.105622        0.024398
# type_of_meal_plan                         0.027698       -0.067543
# required_car_parking_space                0.011429        0.034244
# room_type_reserved                        0.162084        0.478306
# lead_time                                 0.097287       -0.047091
# arrival_year                              0.076719        0.045983
# arrival_month                             0.021841       -0.003076
# arrival_date                              0.026338        0.025482
# market_segment_type                      -0.095543        0.073159
# repeated_guest                           -0.192277       -0.036348
# no_of_previous_cancellations             -0.047426       -0.016390
# no_of_previous_bookings_not_canceled     -0.119166       -0.021189
# avg_price_per_room                        0.296886        0.337728
# no_of_special_requests                    0.189401        0.124486
# booking_status                            0.086920        0.033078
#
#                                       no_of_weekend_nights  no_of_week_nights  \
# no_of_adults                                      0.103316           0.105622
# no_of_children                                    0.029478           0.024398
# no_of_weekend_nights                              1.000000           0.179577
# no_of_week_nights                                 0.179577           1.000000
# type_of_meal_plan                                -0.051485          -0.077883
# required_car_parking_space                       -0.031111          -0.048784
# room_type_reserved                                0.040648           0.062988
# lead_time                                         0.046595           0.149650
# arrival_year                                      0.055357           0.032672
# arrival_month                                    -0.009894           0.037376
# arrival_date                                      0.027304          -0.009305
# market_segment_type                              -0.019804          -0.065301
# repeated_guest                                   -0.067107          -0.099764
# no_of_previous_cancellations                     -0.020690          -0.030080
# no_of_previous_bookings_not_canceled             -0.026312          -0.049344
# avg_price_per_room                               -0.004525           0.022753
# no_of_special_requests                            0.060593           0.045994
# booking_status                                    0.061563           0.092996
#
#                                       type_of_meal_plan  \
# no_of_adults                                   0.027698
# no_of_children                                -0.067543
# no_of_weekend_nights                          -0.051485
# no_of_week_nights                             -0.077883
# type_of_meal_plan                              1.000000
# required_car_parking_space                    -0.030668
# room_type_reserved                            -0.144422
# lead_time                                      0.140077
# arrival_year                                  -0.089153
# arrival_month                                  0.027119
# arrival_date                                   0.021037
# market_segment_type                           -0.165538
# repeated_guest                                -0.068867
# no_of_previous_cancellations                  -0.020829
# no_of_previous_bookings_not_canceled          -0.041373
# avg_price_per_room                             0.042037
# no_of_special_requests                        -0.058062
# booking_status                                 0.079903
#
#                                       required_car_parking_space  \
# no_of_adults                                            0.011429
# no_of_children                                          0.034244
# no_of_weekend_nights                                   -0.031111
# no_of_week_nights                                      -0.048784
# type_of_meal_plan                                      -0.030668
# required_car_parking_space                              1.000000
# room_type_reserved                                      0.039783
# lead_time                                              -0.066445
# arrival_year                                            0.015684
# arrival_month                                          -0.015505
# arrival_date                                           -0.000037
# market_segment_type                                     0.116730
# repeated_guest                                          0.110909
# no_of_previous_cancellations                            0.027106
# no_of_previous_bookings_not_canceled                    0.063810
# avg_price_per_room                                      0.061304
# no_of_special_requests                                  0.087922
# booking_status                                         -0.086185
#
#                                       room_type_reserved  lead_time  \
# no_of_adults                                    0.162084   0.097287
# no_of_children                                  0.478306  -0.047091
# no_of_weekend_nights                            0.040648   0.046595
# no_of_week_nights                               0.062988   0.149650
# type_of_meal_plan                              -0.144422   0.140077
# required_car_parking_space                      0.039783  -0.066445
# room_type_reserved                              1.000000  -0.087376
# lead_time                                      -0.087376   1.000000
# arrival_year                                    0.073994   0.143439
# arrival_month                                  -0.004186   0.136814
# arrival_date                                    0.030176   0.006479
# market_segment_type                             0.166366  -0.312433
# repeated_guest                                 -0.006648  -0.135984
# no_of_previous_cancellations                   -0.001407  -0.045723
# no_of_previous_bookings_not_canceled            0.006089  -0.078137
# avg_price_per_room                              0.405423  -0.062596
# no_of_special_requests                          0.114378  -0.101645
# booking_status                                  0.016327   0.438538
#
#                                       arrival_year  arrival_month  \
# no_of_adults                              0.076719       0.021841
# no_of_children                            0.045983      -0.003076
# no_of_weekend_nights                      0.055357      -0.009894
# no_of_week_nights                         0.032672       0.037376
# type_of_meal_plan                        -0.089153       0.027119
# required_car_parking_space                0.015684      -0.015505
# room_type_reserved                        0.073994      -0.004186
# lead_time                                 0.143439       0.136814
# arrival_year                              1.000000      -0.339689
# arrival_month                            -0.339689       1.000000
# arrival_date                              0.018849      -0.042780
# market_segment_type                       0.081960      -0.026920
# repeated_guest                           -0.018175       0.000341
# no_of_previous_cancellations              0.003919      -0.038615
# no_of_previous_bookings_not_canceled      0.026422      -0.010718
# avg_price_per_room                        0.178605       0.054423
# no_of_special_requests                    0.053205       0.110552
# booking_status                            0.179529      -0.011233
#
#                                       arrival_date  market_segment_type  \
# no_of_adults                              0.026338            -0.095543
# no_of_children                            0.025482             0.073159
# no_of_weekend_nights                      0.027304            -0.019804
# no_of_week_nights                        -0.009305            -0.065301
# type_of_meal_plan                         0.021037            -0.165538
# required_car_parking_space               -0.000037             0.116730
# room_type_reserved                        0.030176             0.166366
# lead_time                                 0.006479            -0.312433
# arrival_year                              0.018849             0.081960
# arrival_month                            -0.042780            -0.026920
# arrival_date                              1.000000             0.007677
# market_segment_type                       0.007677             1.000000
# repeated_guest                           -0.015949             0.297601
# no_of_previous_cancellations             -0.012542             0.074107
# no_of_previous_bookings_not_canceled     -0.001498             0.196916
# avg_price_per_room                        0.017898            -0.043174
# no_of_special_requests                    0.018352             0.202836
# booking_status                            0.010629            -0.048733
#
#                                       repeated_guest  \
# no_of_adults                               -0.192277
# no_of_children                             -0.036348
# no_of_weekend_nights                       -0.067107
# no_of_week_nights                          -0.099764
# type_of_meal_plan                          -0.068867
# required_car_parking_space                  0.110909
# room_type_reserved                         -0.006648
# lead_time                                  -0.135984
# arrival_year                               -0.018175
# arrival_month                               0.000341
# arrival_date                               -0.015949
# market_segment_type                         0.297601
# repeated_guest                              1.000000
# no_of_previous_cancellations                0.390810
# no_of_previous_bookings_not_canceled        0.539156
# avg_price_per_room                         -0.174900
# no_of_special_requests                     -0.011820
# booking_status                             -0.107287
#
#                                       no_of_previous_cancellations  \
# no_of_adults                                             -0.047426
# no_of_children                                           -0.016390
# no_of_weekend_nights                                     -0.020690
# no_of_week_nights                                        -0.030080
# type_of_meal_plan                                        -0.020829
# required_car_parking_space                                0.027106
# room_type_reserved                                       -0.001407
# lead_time                                                -0.045723
# arrival_year                                              0.003919
# arrival_month                                            -0.038615
# arrival_date                                             -0.012542
# market_segment_type                                       0.074107
# repeated_guest                                            0.390810
# no_of_previous_cancellations                              1.000000
# no_of_previous_bookings_not_canceled                      0.468147
# avg_price_per_room                                       -0.063340
# no_of_special_requests                                   -0.003317
# booking_status                                           -0.033728
#
#                                       no_of_previous_bookings_not_canceled  \
# no_of_adults                                                     -0.119166
# no_of_children                                                   -0.021189
# no_of_weekend_nights                                             -0.026312
# no_of_week_nights                                                -0.049344
# type_of_meal_plan                                                -0.041373
# required_car_parking_space                                        0.063810
# room_type_reserved                                                0.006089
# lead_time                                                        -0.078137
# arrival_year                                                      0.026422
# arrival_month                                                    -0.010718
# arrival_date                                                     -0.001498
# market_segment_type                                               0.196916
# repeated_guest                                                    0.539156
# no_of_previous_cancellations                                      0.468147
# no_of_previous_bookings_not_canceled                              1.000000
# avg_price_per_room                                               -0.113684
# no_of_special_requests                                            0.027377
# booking_status                                                   -0.060179
#
#                                       avg_price_per_room  \
# no_of_adults                                    0.296886
# no_of_children                                  0.337728
# no_of_weekend_nights                           -0.004525
# no_of_week_nights                               0.022753
# type_of_meal_plan                               0.042037
# required_car_parking_space                      0.061304
# room_type_reserved                              0.405423
# lead_time                                      -0.062596
# arrival_year                                    0.178605
# arrival_month                                   0.054423
# arrival_date                                    0.017898
# market_segment_type                            -0.043174
# repeated_guest                                 -0.174900
# no_of_previous_cancellations                   -0.063340
# no_of_previous_bookings_not_canceled           -0.113684
# avg_price_per_room                              1.000000
# no_of_special_requests                          0.184381
# booking_status                                  0.142569
#
#                                       no_of_special_requests  booking_status
# no_of_adults                                        0.189401        0.086920
# no_of_children                                      0.124486        0.033078
# no_of_weekend_nights                                0.060593        0.061563
# no_of_week_nights                                   0.045994        0.092996
# type_of_meal_plan                                  -0.058062        0.079903
# required_car_parking_space                          0.087922       -0.086185
# room_type_reserved                                  0.114378        0.016327
# lead_time                                          -0.101645        0.438538
# arrival_year                                        0.053205        0.179529
# arrival_month                                       0.110552       -0.011233
# arrival_date                                        0.018352        0.010629
# market_segment_type                                 0.202836       -0.048733
# repeated_guest                                     -0.011820       -0.107287
# no_of_previous_cancellations                       -0.003317       -0.033728
# no_of_previous_bookings_not_canceled                0.027377       -0.060179
# avg_price_per_room                                  0.184381        0.142569
# no_of_special_requests                              1.000000       -0.253070
# booking_status                                     -0.253070        1.000000

# %% [markdown]
# booking_status 与 lead_time中等相关 arrival_year//repeated_guest//avg_price_per_room//no_of_special_requests低相关

# %% [markdown]
# 尝试使用SVM

# %%
X = df.lead_time
y = df.booking_status
X = X.values.reshape(-1, 1)
y = y.values.reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

clf = svm.SVC()
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)
print(accuracy_score(predicted, y_test))
# Out:
# c:\Program Files\Python310\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.7548470090967564

# %%
df.lead_time
# Out:
# 0        224
# 1          5
# 2          1
# 3        211
# 4         48
#         ...
# 36270     85
# 36271    228
# 36272    148
# 36273     63
# 36274    207
# Name: lead_time, Length: 36275, dtype: int64

# %%
df.
# Out:
#   Cell In[9], line 1
#     df.
#        ^
# SyntaxError: invalid syntax
