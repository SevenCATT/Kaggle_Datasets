# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
test_df = pd.read_csv('C:\\Users\ROG\Documents\GitHub\Kaggle_Datasets\House Prices\data\\test.csv')
train_df = pd.read_csv('C:\\Users\ROG\Documents\GitHub\Kaggle_Datasets\House Prices\data\\train.csv')

# %% [markdown]
# 读取数据的时候报错无效参数，原因是\t是转义符，所以要\\\t

# %% [markdown]
# 更有效的方法可以把所有\替换为\\\

# %% [markdown]
# 建模考虑使用sklearn的线性回归

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
print(X.shape)
y.shape
# Out:
# (1460, 81)
# (1459, 80)

# %%
X = train_df
y = test_df
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 X = train_df
#       2 y = test_df
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
#       5 reg = linear_model.LinearRegression()
#       6 reg.fit(X_train, y_train)
#
# File c:\Program Files\Python310\lib\site-packages\sklearn\model_selection\_split.py:2559, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2556 if n_arrays == 0:
#    2557     raise ValueError("At least one array required as input")
# -> 2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
#    2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#
# File c:\Program Files\Python310\lib\site-packages\sklearn\utils\validation.py:443, in indexable(*iterables)
# ...
